# %%
import pandas as pd

# %%
# !ls data
# Out:
# headlines.txt

# %% [markdown]
# - Read Data

# %%
def read_data(filename):
    with open(filename) as f:
        return pd.DataFrame([line.strip() for line in f], columns=['headline'])

# %%
df = read_data('data/headlines.txt')

# %%
import geonamescache

# %%
gc = geonamescache.GeonamesCache()
countries, cities = gc.get_countries(), gc.get_cities()

# %%
gc.get_cities_by_name('Miami Beach')
# Out:
# [{'4164143': {'geonameid': 4164143,
#    'name': 'Miami Beach',
#    'latitude': 25.79065,
#    'longitude': -80.13005,
#    'countrycode': 'US',
#    'population': 92312,
#    'timezone': 'America/New_York',
#    'admin1code': 'FL'}}]

# %%
import unidecode
country_names = [unidecode.unidecode(country_dict['name']) for country_dict in countries.values()]
city_names = [unidecode.unidecode(city_dict['name']) for city_dict in cities.values()]
city_names = sorted(city_names, key=lambda x: len(x), reverse=True)
country_names  = sorted(country_names, key=lambda x: len(x), reverse=True)

# %%
import re

# %%
cities_regex = '|'.join(city_names)

# %%
countries_regex = '|'.join(country_names)

# %%
full_cities_regex    = '\\b(' + cities_regex + ')\\b'
# print(full_cities_regex[-1])
full_countries_regex = '\\b(' + countries_regex + ')\\b'
full_cities_regex = re.compile(full_cities_regex)
full_countries_regex = re.compile(full_countries_regex)

# %%
text = 'Miami Beach'
def city_matcher(text, full_cities_regex):
    match = full_cities_regex.search(text)
    return text[match.start():match.end()] if match is not None else None
city_matcher(text,full_cities_regex)
# Out:
# 'Miami Beach'

# %%
# text = 'Zika Concerns are Spreading in Houston and Brazil'
# def cities_matcher(text, full_cities_regex):
#     matches = full_cities_regex.findall(text)
#     #print(matches[1][0])
#     lst_matches = [match[0] for match in matches] if len(matches)>0 else None
#     return ', '.join(lst_matches) if lst_matches is not None else None
# cities_matcher(text,full_cities_regex)

# %%
df['cities']    = [city_matcher(unidecode.unidecode(headline),full_cities_regex) for headline in df['headline']]
df['countries'] = [city_matcher(unidecode.unidecode(headline),full_countries_regex) for headline in df['headline']]

# %%
df.fillna(value=pd.np.nan, inplace=True)
df
# Out:
#                                               headline         cities  \
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil         Recife
# 4              Dallas man comes down with case of Zika         Dallas
# ..                                                 ...            ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      Jerusalem
# 646              More Zika patients reported in Indang         Indang
# 647  Suva authorities confirmed the spread of Rotav...           Suva
# 648         More Zika patients reported in Bella Vista    Bella Vista
# 649                     Zika Outbreak in Wichita Falls  Wichita Falls
#
#     countries
# 0         NaN
# 1         NaN
# 2         NaN
# 3      Brazil
# 4         NaN
# ..        ...
# 645       NaN
# 646       NaN
# 647       NaN
# 648       NaN
# 649       NaN
#
# [650 rows x 3 columns]

# %% [markdown]
# - let's save progress

# %%
df.to_json('result_json.json',orient='records')

# %%
ls
# Out:
# 1. Extracting City and Country Information from News Headlines.ipynb
# README.md
# data/
# environment.yml
# result_json.json
# step1_extraction.ipynb

# %%
import json
with open('result_json.json', "r") as fin:
    check_data = json.loads(fin.read())

# %%
check_data
# Out:
# [{'headline': 'Zika Outbreak Hits Miami',
#   'cities': 'Miami',
#   'countries': None},
#  {'headline': 'Could Zika Reach New York City?',
#   'cities': 'New York City',
#   'countries': None},
#  {'headline': 'First Case of Zika in Miami Beach',
#   'cities': 'Miami Beach',
#   'countries': None},
#  {'headline': 'Mystery Virus Spreads in Recife, Brazil',
#   'cities': 'Recife',
#   'countries': 'Brazil'},
#  {'headline': 'Dallas man comes down with case of Zika',
#   'cities': 'Dallas',
#   'countries': None},
#  {'headline': 'Trinidad confirms first Zika case',
#   'cities': 'Trinidad',
#   'countries': None},
#  {'headline': 'Zika Concerns are Spreading in Houston',
#   'cities': 'Houston',
#   'countries': None},
#  {'headline': 'Geneve Scientists Battle to Find Cure',
#   'cities': 'Geneve',
#   'countries': None},
#  {'headline': 'The CDC in Atlanta is Growing Worried',
#   'cities': 'Atlanta',
#   'countries': None},
#  {'headline': 'Zika Infested Monkeys in Sao Paulo',
#   'cities': 'Sao Paulo',
#   'countries': None},
#  {'headline': 'Brownsville teen contracts Zika virus',
#   'cities': 'Brownsville',
#   'countries': None},
#  {'headline': 'Mosquito control efforts in St. Louis take new tactics with Zika threat',
#   'cities': 'St. Louis',
#   'countries': None},
#  {'headline': 'San Juan reports 1st U.S. Zika-related death amid outbreak',
#   'cities': 'San Juan',
#   'countries': None},
#  {'headline': 'Flu outbreak in Galveston, Texas',
#   'cities': 'Galveston',
#   'countries': None},
#  {'headline': 'Zika alert – Manila now threatened',
#   'cities': 'Manila',
#   'countries': None},
#  {'headline': 'Zika afflicts 7 in Iloilo City',
#   'cities': 'Iloilo',
#   'countries': None},
#  {'headline': 'New Los Angeles Hairstyle goes Viral',
#   'cities': 'Los Angeles',
#   'countries': None},
#  {'headline': 'Louisiana Zika cases up to 26',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Orlando volunteers aid Zika research',
#   'cities': 'Orlando',
#   'countries': None},
#  {'headline': 'Zika infects pregnant woman in Cebu',
#   'cities': None,
#   'countries': None},
#  {'headline': "Chicago's First Zika Case Confirmed",
#   'cities': 'Chicago',
#   'countries': None},
#  {'headline': 'Tampa Bay Area Zika Case Count Climbs',
#   'cities': 'Tampa',
#   'countries': None},
#  {'headline': 'Bad Water Leads to Sickness in Flint, Michigan',
#   'cities': 'Flint',
#   'countries': None},
#  {'headline': 'Baltimore plans for Zika virus',
#   'cities': 'Baltimore',
#   'countries': None},
#  {'headline': 'London Health Unit Tracks Mad Cow Disease',
#   'cities': 'London',
#   'countries': None},
#  {'headline': "Zika cases in Vietnam's Ho Chi Minh City surge",
#   'cities': 'Ho Chi Minh City',
#   'countries': 'Vietnam'},
#  {'headline': 'Philadelphia experts track pandemic',
#   'cities': 'Philadelphia',
#   'countries': None},
#  {'headline': 'Flu season hits Boston', 'cities': 'Boston', 'countries': None},
#  {'headline': 'Scientists in Paris to look for answers',
#   'cities': 'Paris',
#   'countries': None},
#  {'headline': 'Key Zika Findings in San Diego Institute',
#   'cities': 'San Diego',
#   'countries': None},
#  {'headline': 'Thailand-Zika Virus in Bangkok',
#   'cities': 'Bangkok',
#   'countries': 'Thailand'},
#  {'headline': 'Beijing team cracks Zika secret',
#   'cities': 'Beijing',
#   'countries': None},
#  {'headline': 'Zika spreading to Salvador',
#   'cities': 'Salvador',
#   'countries': None},
#  {'headline': 'Kuala Lumpur is Hit By Zika Threat',
#   'cities': 'Kuala Lumpur',
#   'countries': None},
#  {'headline': 'First Zika case confirmed in Yangon',
#   'cities': 'Yangon',
#   'countries': None},
#  {'headline': 'Tallahassee Doctors Discuss Zika Virus',
#   'cities': 'Tallahassee',
#   'countries': None},
#  {'headline': 'Zika Virus Reaches San Francisco',
#   'cities': 'San Francisco',
#   'countries': None},
#  {'headline': 'New Vaccine on Trial in Bethesda District',
#   'cities': 'Bethesda',
#   'countries': None},
#  {'headline': 'Townsville Zika tests inconclusive',
#   'cities': 'Townsville',
#   'countries': None},
#  {'headline': 'Mandaluyong City under Siege by Virus',
#   'cities': 'Mandaluyong City',
#   'countries': None},
#  {'headline': 'Hepatitis E re-emerges in Santa Rosa',
#   'cities': 'Santa Rosa',
#   'countries': None},
#  {'headline': 'Zika worries in San Salvador',
#   'cities': 'San Salvador',
#   'countries': None},
#  {'headline': 'Zika virus reported in Cleveland',
#   'cities': 'Cleveland',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Austin',
#   'cities': 'Austin',
#   'countries': None},
#  {'headline': 'Zika outbreak in Piracicaba, Brazil',
#   'cities': 'Piracicaba',
#   'countries': 'Brazil'},
#  {'headline': 'Lima tries to address Zika Concerns',
#   'cities': 'Lima',
#   'countries': None},
#  {'headline': 'More people in Toronto are infected with Hepatitis E every year',
#   'cities': 'Toronto',
#   'countries': None},
#  {'headline': '18 new Zika Cases in Bogota',
#   'cities': 'Bogota',
#   'countries': None},
#  {'headline': 'Spanish Flu Sighted in Antigua',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Brisbane is infested with Meningitis',
#   'cities': 'Brisbane',
#   'countries': None},
#  {'headline': 'Cholera outbreak in Dakar',
#   'cities': 'Dakar',
#   'countries': None},
#  {'headline': 'Zika Virus Transmission Detected in Havana',
#   'cities': 'Havana',
#   'countries': None},
#  {'headline': 'Zika symtomps spotted in Key West',
#   'cities': 'Key West',
#   'countries': None},
#  {'headline': 'Case of Measles Reported in Vancouver',
#   'cities': 'Vancouver',
#   'countries': None},
#  {'headline': 'Seattle scientists get $500,000 grant to pursue Zika vaccine New 7:50 pm',
#   'cities': 'Seattle',
#   'countries': None},
#  {'headline': 'Nashville takes precautions against Zika',
#   'cities': 'Nashville',
#   'countries': None},
#  {'headline': 'Saint Croix under Zika threat',
#   'cities': 'Saint Croix',
#   'countries': None},
#  {'headline': 'Fort Collins Encounters Severe Symptoms of Gonorrhea',
#   'cities': 'Fort Collins',
#   'countries': None},
#  {'headline': 'Zika surfaces in Klang, Malaysia',
#   'cities': 'Klang',
#   'countries': 'Malaysia'},
#  {'headline': 'Rumors about Meningitis spreading in Guatemala City have been refuted',
#   'cities': 'Guatemala City',
#   'countries': 'Guatemala'},
#  {'headline': 'Madison lab developing vaccine against Zika virus [The Wisconsin State Journal]',
#   'cities': 'Madison',
#   'countries': None},
#  {'headline': 'New Zika Case Confirmed in Sarasota County',
#   'cities': 'Sarasota',
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Entebbe after Rabies Vaccine becomes Mandatory',
#   'cities': 'Entebbe',
#   'countries': None},
#  {'headline': 'Carnival under threat in Rio De Janeiro due to Zika outbreak',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Second Zika Paitient in Brasilia',
#   'cities': 'Brasilia',
#   'countries': None},
#  {'headline': 'Jacksonville man hit by Zika',
#   'cities': 'Jacksonville',
#   'countries': None},
#  {'headline': 'Schools in Shenzhen Closed Due to Malaria Outbreak',
#   'cities': 'Shenzhen',
#   'countries': None},
#  {'headline': 'Caracas patient dies', 'cities': 'Caracas', 'countries': None},
#  {'headline': 'More Quezon City Zika Transmissions',
#   'cities': 'Quezon City',
#   'countries': None},
#  {'headline': 'Schools in Sydney Closed Due to Respiratory Syncytial Virus Outbreak',
#   'cities': 'Sydney',
#   'countries': None},
#  {'headline': "Mumbai's Health Minister warns of more Zika cases",
#   'cities': 'Mumbai',
#   'countries': None},
#  {'headline': 'Pune woman diagnosed with Zika',
#   'cities': 'Pune',
#   'countries': None},
#  {'headline': 'Hospitals in Hanoi fill up with Zika patients',
#   'cities': 'Hanoi',
#   'countries': None},
#  {'headline': 'Zika case reported in Oton', 'cities': None, 'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Bronchitis in Silver Spring',
#   'cities': 'Silver Spring',
#   'countries': None},
#  {'headline': 'Zika: Delhi for strict monitoring',
#   'cities': 'Delhi',
#   'countries': None},
#  {'headline': 'Hillsborough uses innovative trap against Zika 20 minutes ago',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Belize City under threat from Zika',
#   'cities': 'Belize City',
#   'countries': 'Belize'},
#  {'headline': 'Student sick in Campinas, Brazil',
#   'cities': 'Campinas',
#   'countries': 'Brazil'},
#  {'headline': 'More Zika cases in Soyapango',
#   'cities': 'Soyapango',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Mad Cow Disease in Rome',
#   'cities': 'Rome',
#   'countries': None},
#  {'headline': 'Seoul confirms 14th Zika infection',
#   'cities': 'Seoul',
#   'countries': None},
#  {'headline': 'Hepatitis B Vaccine is now Required in Quebec',
#   'cities': 'Quebec',
#   'countries': None},
#  {'headline': 'Zika outbreak spreads to Mexico City',
#   'cities': 'Mexico City',
#   'countries': 'Mexico'},
#  {'headline': 'Rochester authorities confirmed the spread of Dengue',
#   'cities': 'Rochester',
#   'countries': None},
#  {'headline': 'El Paso fighting Zika', 'cities': 'El Paso', 'countries': None},
#  {'headline': 'Visitor to Cucuta contracts Zika',
#   'cities': 'Cucuta',
#   'countries': None},
#  {'headline': 'Zika now spreading through Jakarta',
#   'cities': 'Jakarta',
#   'countries': None},
#  {'headline': 'Maka City Experiences Influenza Outbreak',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Salt Lake City tests new cure for Respiratory Syncytial Virus',
#   'cities': 'Salt Lake City',
#   'countries': None},
#  {'headline': 'Zika San Antonio Patient Speaks Out',
#   'cities': 'San Antonio',
#   'countries': None},
#  {'headline': 'Ebola outbreak in Kampala',
#   'cities': 'Kampala',
#   'countries': None},
#  {'headline': 'Precautionary Zika measures in Rockhampton',
#   'cities': 'Rockhampton',
#   'countries': None},
#  {'headline': 'Zika arrives in Tegucigalpa',
#   'cities': 'Tegucigalpa',
#   'countries': None},
#  {'headline': 'New Zika Case Confirmed in Belo Horizonte',
#   'cities': 'Belo Horizonte',
#   'countries': None},
#  {'headline': 'Case of Hepatitis E Reported in Melbourne',
#   'cities': 'Melbourne',
#   'countries': None},
#  {'headline': 'First Columbus Zika case',
#   'cities': 'Columbus',
#   'countries': None},
#  {'headline': 'New medicine wipes out Tuberculosis in Taipei',
#   'cities': 'Taipei',
#   'countries': None},
#  {'headline': 'Zika Patient in Seminole, Florida',
#   'cities': 'Seminole',
#   'countries': None},
#  {'headline': 'Antipolo under threat from Zika Virus',
#   'cities': 'Antipolo',
#   'countries': None},
#  {'headline': 'Spreading Zika reaches Bacoor',
#   'cities': 'Bacoor',
#   'countries': None},
#  {'headline': 'Can Zika make it here to Vero Beach?',
#   'cities': 'Can',
#   'countries': None},
#  {'headline': 'Zika afflicts patient in Calamba',
#   'cities': 'Calamba',
#   'countries': None},
#  {'headline': 'Hollywood Outbreak Film Premieres',
#   'cities': 'Hollywood',
#   'countries': None},
#  {'headline': 'Petaling Jaya man ill from Zika',
#   'cities': 'Petaling Jaya',
#   'countries': None},
#  {'headline': 'Malaria is Spreading in Johannesburg',
#   'cities': 'Johannesburg',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Norovirus in Buenos Aires',
#   'cities': 'Buenos Aires',
#   'countries': None},
#  {'headline': 'Guangzhou Patient in Critical Condition after Contracting Swine Flu',
#   'cities': 'Guangzhou',
#   'countries': None},
#  {'headline': 'Doral hit by Deadly Virus',
#   'cities': 'Doral',
#   'countries': None},
#  {'headline': 'Tokyo Encounters Severe Symptoms of Meningitis',
#   'cities': 'Tokyo',
#   'countries': None},
#  {'headline': 'Rabies Exposure in Hamilton',
#   'cities': 'Hamilton',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Influenza in Savannah',
#   'cities': 'Savannah',
#   'countries': None},
#  {'headline': 'Zika Outbreak in Hyderabad',
#   'cities': 'Hyderabad',
#   'countries': None},
#  {'headline': 'Birmingham Residents Recieve Rabies vaccine',
#   'cities': 'Birmingham',
#   'countries': None},
#  {'headline': 'Is Zika virus in Majuro?',
#   'cities': 'Majuro',
#   'countries': None},
#  {'headline': 'Spreading Zika ruining Cancun fun',
#   'cities': 'Cancun',
#   'countries': None},
#  {'headline': 'Cancun hit by Outbreak of Party Fever!',
#   'cities': 'Cancun',
#   'countries': None},
#  {'headline': 'HIV has Arrived in Fairfax',
#   'cities': 'Fairfax',
#   'countries': None},
#  {'headline': 'Spanish Flu Outbreak in Barcelona',
#   'cities': 'Barcelona',
#   'countries': None},
#  {'headline': 'Santa Barbara tests new cure for Hepatitis C',
#   'cities': 'Santa Barbara',
#   'countries': None},
#  {'headline': 'Spring break ruined by Zika in Fort Lauderdale',
#   'cities': 'Spring',
#   'countries': None},
#  {'headline': 'Villavicencio under Zika threat',
#   'cities': 'Villavicencio',
#   'countries': None},
#  {'headline': 'Two more Zika cases confirmed in Laredo',
#   'cities': 'Laredo',
#   'countries': None},
#  {'headline': 'New Delhi Addressing Zika Concerns',
#   'cities': 'New Delhi',
#   'countries': None},
#  {'headline': 'New Zika Case in Kota Kinabalu, Malaysia',
#   'cities': 'Kota Kinabalu',
#   'countries': 'Malaysia'},
#  {'headline': 'New medicine wipes out West Nile Virus in Ventura',
#   'cities': 'Ventura',
#   'countries': None},
#  {'headline': 'Meningitis re-emerges in Nassau',
#   'cities': 'Nassau',
#   'countries': None},
#  {'headline': 'Zika reaches Johor Bahru, Malaysia',
#   'cities': 'Johor Bahru',
#   'countries': 'Malaysia'},
#  {'headline': 'Nha Trang Zika Outbreak',
#   'cities': 'Nha Trang',
#   'countries': None},
#  {'headline': 'First Zika Case in Cincinnati',
#   'cities': 'Cincinnati',
#   'countries': None},
#  {'headline': 'Molo Cholera Spread Causing Concern',
#   'cities': 'Molo',
#   'countries': None},
#  {'headline': 'Norovirus Exposure in Hong Kong',
#   'cities': 'Hong Kong',
#   'countries': 'Hong Kong'},
#  {'headline': '19 new Zika Cases in Sengkang',
#   'cities': 'Sengkang',
#   'countries': None},
#  {'headline': 'Zika cases concern Charlotte residents',
#   'cities': 'Charlotte',
#   'countries': None},
#  {'headline': 'Batangas Tourism Takes a Hit as Virus Spreads',
#   'cities': 'Batangas',
#   'countries': None},
#  {'headline': 'Johannesburg Patient in Critical Condition after Contracting Pneumonia',
#   'cities': 'Johannesburg',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Bacolod City',
#   'cities': 'Bacolod City',
#   'countries': None},
#  {'headline': 'Respiratory Syncytial Virus Keeps Spreading in Masaya',
#   'cities': 'Masaya',
#   'countries': None},
#  {'headline': 'Spike of Pneumonia Cases in Springfield',
#   'cities': 'Springfield',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Mcallen',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Zika case reported in Jupiter',
#   'cities': 'Jupiter',
#   'countries': None},
#  {'headline': 'Zika virus confirmed in Westchester',
#   'cities': 'Westchester',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Tuberculosis in Abuja',
#   'cities': 'Abuja',
#   'countries': None},
#  {'headline': 'Rumors about Hepatitis D Spreading in San Juan Capistrano have been Refuted',
#   'cities': 'San Juan Capistrano',
#   'countries': None},
#  {'headline': 'The Spread of Measles in Spokane has been Confirmed',
#   'cities': 'Spokane',
#   'countries': None},
#  {'headline': 'Zika alert for Rio Grande Valley residents',
#   'cities': 'Rio Grande',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Colombo',
#   'cities': 'Colombo',
#   'countries': None},
#  {'headline': 'West Nile Virus Outbreak in Louisville',
#   'cities': 'Louisville',
#   'countries': None},
#  {'headline': 'New details in Baton Rouge cop killings',
#   'cities': 'Baton Rouge',
#   'countries': None},
#  {'headline': 'Hepatitis B has not Left Florence',
#   'cities': 'Florence',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Pensacola',
#   'cities': 'Pensacola',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Corpus Christi',
#   'cities': 'Corpus Christi',
#   'countries': None},
#  {'headline': 'How to Avoid Rhinovirus in Lemon Grove',
#   'cities': 'Lemon Grove',
#   'countries': None},
#  {'headline': 'Rumors about Rotavirus spreading in Huntsville have been refuted',
#   'cities': 'Huntsville',
#   'countries': None},
#  {'headline': 'Rhinovirus has Arrived in Athens',
#   'cities': 'Athens',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Panama City',
#   'cities': 'Panama City',
#   'countries': 'Panama'},
#  {'headline': 'West Nile Virus Outbreak in Saint Johns',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Measles has not Left Brooklyn',
#   'cities': 'Brooklyn',
#   'countries': None},
#  {'headline': 'Escondido neighborhood to get sprayed for Zika virus',
#   'cities': 'Escondido',
#   'countries': None},
#  {'headline': 'Zika in Belmont, Belmont worry',
#   'cities': 'Belmont',
#   'countries': None},
#  {'headline': 'Influenza has not Left Sacramento',
#   'cities': 'Sacramento',
#   'countries': None},
#  {'headline': 'Veracruz hit by Zika Concerns',
#   'cities': 'Veracruz',
#   'countries': None},
#  {'headline': 'Case of Mumps Reported in Dayton',
#   'cities': 'Dayton',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Dengue in Kingston',
#   'cities': 'Kingston',
#   'countries': None},
#  {'headline': 'Gainesville Deals with Disease Concerns',
#   'cities': 'Gainesville',
#   'countries': None},
#  {'headline': 'Montevideo Encounters Severe Symptoms of Rotavirus',
#   'cities': 'Montevideo',
#   'countries': None},
#  {'headline': 'Varicella Keeps Spreading in Detroit',
#   'cities': 'Detroit',
#   'countries': None},
#  {'headline': 'Arhus is infested with Bronchitis',
#   'cities': 'Arhus',
#   'countries': None},
#  {'headline': 'Zika Troubles come to Niteroi',
#   'cities': 'Niteroi',
#   'countries': None},
#  {'headline': 'Zika cases in Singapore reach 393',
#   'cities': 'Singapore',
#   'countries': 'Singapore'},
#  {'headline': 'Manhattan Residents Recieve HIV vaccine',
#   'cities': 'Manhattan',
#   'countries': None},
#  {'headline': 'Zika arrives in Miri', 'cities': 'Miri', 'countries': None},
#  {'headline': 'Rumors about Dengue Spreading in Syracuse have been Refuted',
#   'cities': 'Syracuse',
#   'countries': None},
#  {'headline': 'Will Norovirus vaccine help Raleigh?',
#   'cities': 'Raleigh',
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Auckland after Hepatitis D Vaccine becomes Mandatory',
#   'cities': 'Auckland',
#   'countries': None},
#  {'headline': 'How to Avoid Gonorrhea in Shreveport',
#   'cities': 'Shreveport',
#   'countries': None},
#  {'headline': 'Ithaca is infested with Dengue',
#   'cities': 'Ithaca',
#   'countries': None},
#  {'headline': 'Will MCD vaccine help Strasbourg?',
#   'cities': 'Strasbourg',
#   'countries': None},
#  {'headline': 'New medicine wipes out Measles in Fresno',
#   'cities': 'Fresno',
#   'countries': None},
#  {'headline': 'BREAKING – Zika in Missoula',
#   'cities': 'Missoula',
#   'countries': None},
#  {'headline': 'Zika arrives in Santos', 'cities': 'Santos', 'countries': None},
#  {'headline': 'Sick Livestock Leads to Serious Trouble for Belfort',
#   'cities': 'Belfort',
#   'countries': None},
#  {'headline': 'Hepatitis E has not Left Libreville',
#   'cities': 'Libreville',
#   'countries': None},
#  {'headline': 'New medicine wipes out Chikungunya in Tucson',
#   'cities': 'Tucson',
#   'countries': None},
#  {'headline': 'Norovirus has Arrived in Winnipeg',
#   'cities': 'Winnipeg',
#   'countries': None},
#  {'headline': 'Hepatitis B Comes to Kansas City',
#   'cities': 'Kansas City',
#   'countries': None},
#  {'headline': 'More Patients in Cambridge are Getting Diagnosed with Chickenpox',
#   'cities': 'Cambridge',
#   'countries': None},
#  {'headline': 'Chikungunya Exposure in Toledo',
#   'cities': 'Toledo',
#   'countries': None},
#  {'headline': 'Is Lafayette prepared to combat Zika?',
#   'cities': 'Lafayette',
#   'countries': None},
#  {'headline': 'Mecca tests new cure for Chikungunya',
#   'cities': 'Mecca',
#   'countries': None},
#  {'headline': 'Zika arrives in San Benito',
#   'cities': 'San Benito',
#   'countries': None},
#  {'headline': 'Syphilis Outbreak in Harrisburg',
#   'cities': 'Harrisburg',
#   'countries': None},
#  {'headline': 'Zika Arrives in North Miami',
#   'cities': 'North Miami',
#   'countries': None},
#  {'headline': 'Urbana Encounters Severe Symptoms of Meningitis',
#   'cities': 'Urbana',
#   'countries': None},
#  {'headline': 'Pittsburgh Residents Recieve Norovirus vaccine',
#   'cities': 'Pittsburgh',
#   'countries': None},
#  {'headline': 'Chikungunya Hits Denver',
#   'cities': 'Denver',
#   'countries': None},
#  {'headline': 'Zika case recorded in Tunapuna »',
#   'cities': 'Tunapuna',
#   'countries': None},
#  {'headline': 'Spike of Respiratory Syncytial Virus Cases in Mandalay',
#   'cities': 'Mandalay',
#   'countries': None},
#  {'headline': 'HIV Keeps Spreading in Boulder',
#   'cities': 'Boulder',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Joao Pessoa',
#   'cities': 'Joao Pessoa',
#   'countries': None},
#  {'headline': 'Will Tuberculosis vaccine help Rockville?',
#   'cities': 'Rockville',
#   'countries': None},
#  {'headline': 'Mad Cow Disease Re-emerges in Chatham',
#   'cities': 'Chatham',
#   'countries': None},
#  {'headline': 'Zika Virus Arrives in Ontario',
#   'cities': 'Ontario',
#   'countries': None},
#  {'headline': 'Mad Cow Disease Hits Naples',
#   'cities': 'Naples',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Davao',
#   'cities': 'Davao',
#   'countries': None},
#  {'headline': 'The Spread of Chikungunya in Arcadia has been Confirmed',
#   'cities': 'Arcadia',
#   'countries': None},
#  {'headline': 'Oxford tests new cure for HIV',
#   'cities': 'Oxford',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Stephenville',
#   'cities': 'Stephenville',
#   'countries': None},
#  {'headline': 'Providence Encounters Severe Symptoms of Dengue',
#   'cities': 'Providence',
#   'countries': None},
#  {'headline': 'Tests negative on Windsor Zika carriers',
#   'cities': 'Windsor',
#   'countries': None},
#  {'headline': 'Zika battle outlined at Valdosta meeting',
#   'cities': 'Valdosta',
#   'countries': None},
#  {'headline': 'Zika case reported in Coral Gables',
#   'cities': 'Coral Gables',
#   'countries': None},
#  {'headline': 'Hepatitis C Outbreak in Danbury',
#   'cities': 'Danbury',
#   'countries': None},
#  {'headline': 'Chickenpox has Arrived in Chula Vista',
#   'cities': 'Chula Vista',
#   'countries': None},
#  {'headline': 'Syphilis Hits Jefferson',
#   'cities': 'Jefferson',
#   'countries': None},
#  {'headline': 'Will HIV vaccine help Las Vegas?',
#   'cities': 'Las Vegas',
#   'countries': None},
#  {'headline': 'Zika arrives in West Palm Beach',
#   'cities': 'West Palm Beach',
#   'countries': None},
#  {'headline': 'Mobile authorities confirmed the spread of Bronchitis',
#   'cities': 'Mobile',
#   'countries': None},
#  {'headline': 'Zika spreads to Daytona Beach',
#   'cities': 'Daytona Beach',
#   'countries': None},
#  {'headline': 'Lausanne Residents Recieve Meningitis vaccine',
#   'cities': 'Lausanne',
#   'countries': None},
#  {'headline': 'Rhinovirus Comes to San Jose',
#   'cities': 'San Jose',
#   'countries': None},
#  {'headline': 'Spike of Chlamydia Cases in Farmington',
#   'cities': 'Farmington',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Rotavirus in Union',
#   'cities': 'Union',
#   'countries': None},
#  {'headline': 'Rumors about Hepatitis D spreading in Albany have been refuted',
#   'cities': 'Albany',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Bello',
#   'cities': 'Bello',
#   'countries': None},
#  {'headline': 'Will Meningitis vaccine help Hamburg?',
#   'cities': 'Hamburg',
#   'countries': None},
#  {'headline': 'Madera Patient in Critical Condition after Contracting Rabies',
#   'cities': 'Madera',
#   'countries': None},
#  {'headline': 'Zika Virus Detected in Lubbock',
#   'cities': 'Lubbock',
#   'countries': None},
#  {'headline': 'Malaria re-emerges in Boise',
#   'cities': 'Boise',
#   'countries': None},
#  {'headline': 'Varicella re-emerges in Lagos',
#   'cities': 'Lagos',
#   'countries': None},
#  {'headline': 'Vericella spreading in Ibadan',
#   'cities': 'Ibadan',
#   'countries': None},
#  {'headline': 'Schools in Birmingham Closed Due to Measles Outbreak',
#   'cities': 'Birmingham',
#   'countries': None},
#  {'headline': 'How to Avoid Hepatitis B in Waldorf',
#   'cities': 'Waldorf',
#   'countries': None},
#  {'headline': 'More people in Mclean are infected with Hepatitis A every year',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Malaria Exposure in Sussex', 'cities': None, 'countries': None},
#  {'headline': 'Tuberculosis Outbreak in Newark',
#   'cities': 'Newark',
#   'countries': None},
#  {'headline': "Zika Virus Sparks 'International Concern'",
#   'cities': 'Sparks',
#   'countries': None},
#  {'headline': 'Spike of Chlamydia Cases in Berlin',
#   'cities': 'Berlin',
#   'countries': None},
#  {'headline': 'Zika-carrying mosquitoes discovered in Ardmore',
#   'cities': 'Ardmore',
#   'countries': None},
#  {'headline': 'Zika Mosquitoes May Have Bred in Bromeliads, Florida Officials Say',
#   'cities': 'Florida',
#   'countries': None},
#  {'headline': 'More Livestock in Fontainebleau are infected with Mad Cow Disease',
#   'cities': 'Fontainebleau',
#   'countries': None},
#  {'headline': 'Frisco Woman Tests Positive For Zika Virus',
#   'cities': 'Frisco',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Norovirus in Dubai',
#   'cities': 'Dubai',
#   'countries': None},
#  {'headline': 'Benton Residents Recieve Pneumonia vaccine',
#   'cities': 'Benton',
#   'countries': None},
#  {'headline': 'Case of Hepatitis A Reported in Calgary',
#   'cities': 'Calgary',
#   'countries': None},
#  {'headline': 'Zika Outbreak in Pinewood',
#   'cities': 'Pinewood',
#   'countries': None},
#  {'headline': 'Will Swine Flu vaccine help Ljubljana?',
#   'cities': 'Ljubljana',
#   'countries': None},
#  {'headline': 'Bronchitis re-emerges in Tehran',
#   'cities': 'Tehran',
#   'countries': None},
#  {'headline': 'Greenwich Establishes Zika Task Force',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Mad Cow case in Murcia', 'cities': 'Murcia', 'countries': None},
#  {'headline': 'Mad Cow Disease Spreads to Margate',
#   'cities': 'Margate',
#   'countries': None},
#  {'headline': 'Zika Strikes St. Petersburg',
#   'cities': 'St. Petersburg',
#   'countries': None},
#  {'headline': 'Will West Nile Virus vaccine help Parsons?',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Will the Mad Cow Outbreak Reach Vienna?',
#   'cities': 'Vienna',
#   'countries': None},
#  {'headline': 'More Patients in Orange are Getting Diagnosed with Chickenpox',
#   'cities': 'Orange',
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Richmond after Mumps Vaccine becomes Mandatory',
#   'cities': 'Richmond',
#   'countries': None},
#  {'headline': 'Meningitis re-emerges in Medina',
#   'cities': 'Medina',
#   'countries': None},
#  {'headline': 'Yulee takes a hit from Spreading Sickness',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Four cases of Zika in Hidalgo County',
#   'cities': 'Hidalgo',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Hollywood',
#   'cities': 'Hollywood',
#   'countries': None},
#  {'headline': 'Zika arrives in Oaxaca', 'cities': 'Oaxaca', 'countries': None},
#  {'headline': 'More people in Durham are infected with Chlamydia every year',
#   'cities': 'Durham',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Gonorrhea in Taoyuan City',
#   'cities': 'Taoyuan City',
#   'countries': None},
#  {'headline': 'Swine Flu re-emerges in La Jolla',
#   'cities': 'La Jolla',
#   'countries': None},
#  {'headline': 'Tuberculosis Outbreak in Hartford',
#   'cities': 'Hartford',
#   'countries': None},
#  {'headline': 'Rumors about Mumps Spreading in New Bedford have been Refuted',
#   'cities': 'New Bedford',
#   'countries': None},
#  {'headline': 'Respiratory Syncytial Virus Vaccine is now Required in Tulsa',
#   'cities': 'Tulsa',
#   'countries': None},
#  {'headline': 'More people in Indianapolis are infected with Norovirus every year',
#   'cities': 'Indianapolis',
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Dhaka after Measles Vaccine becomes Mandatory',
#   'cities': 'Dhaka',
#   'countries': None},
#  {'headline': 'Albany Residents Recieve Respiratory Syncytial Virus vaccine',
#   'cities': 'Albany',
#   'countries': None},
#  {'headline': 'The Spread of Chikungunya in Davidson has been Confirmed',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Rotavirus Vaccine is now Required in Starkville',
#   'cities': 'Starkville',
#   'countries': None},
#  {'headline': 'Schools in Yaounde Closed Due to Mumps Outbreak',
#   'cities': 'Yaounde',
#   'countries': None},
#  {'headline': 'More people in Nadi are infected with HIV every year',
#   'cities': 'Nadi',
#   'countries': None},
#  {'headline': 'Tocumen tests new cure for Hepatitis A',
#   'cities': 'Tocumen',
#   'countries': None},
#  {'headline': 'Phnom Penh hit by Zika Threat',
#   'cities': 'Phnom Penh',
#   'countries': None},
#  {'headline': 'Zika Troubles come to Harlingen',
#   'cities': 'Harlingen',
#   'countries': None},
#  {'headline': 'Zika spreads to Barranquilla',
#   'cities': 'Barranquilla',
#   'countries': None},
#  {'headline': 'Milwaukee authorities confirmed the spread of Rhinovirus',
#   'cities': 'Milwaukee',
#   'countries': None},
#  {'headline': 'Mad Cow Disease Hits Rotterdam',
#   'cities': 'Rotterdam',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Arlington',
#   'cities': 'Arlington',
#   'countries': None},
#  {'headline': 'West Nile Virus Hits Yogyakarta',
#   'cities': 'Yogyakarta',
#   'countries': None},
#  {'headline': 'More Patients in Dublin are Getting Diagnosed with Bronchitis',
#   'cities': 'Dublin',
#   'countries': None},
#  {'headline': 'Rumors about Tuberculosis Spreading in Baud have been Refuted',
#   'cities': 'Baud',
#   'countries': None},
#  {'headline': 'Rumors about West Nile Virus Spreading in Salem have been Refuted',
#   'cities': 'Salem',
#   'countries': None},
#  {'headline': 'St. Catharines Patient in Critical Condition after Contracting Dengue',
#   'cities': 'St. Catharines',
#   'countries': None},
#  {'headline': 'Zika case reported in Los Fresnos',
#   'cities': None,
#   'countries': None},
#  {'headline': 'More Zika patients reported in Camacari',
#   'cities': 'Camacari',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Pasig City',
#   'cities': 'Pasig City',
#   'countries': None},
#  {'headline': 'Zika Troubles come to Kampong Cham',
#   'cities': 'Kampong Cham',
#   'countries': None},
#  {'headline': 'Zika case reported in Rizal',
#   'cities': 'Rizal',
#   'countries': None},
#  {'headline': 'Zika Spreads to Palm Beach Gardens',
#   'cities': 'Palm Beach Gardens',
#   'countries': None},
#  {'headline': 'More people in Saint Petersburg are infected with Varicella every year',
#   'cities': 'Saint Petersburg',
#   'countries': None},
#  {'headline': 'Spike of Herpes Cases in Meriden',
#   'cities': 'Meriden',
#   'countries': None},
#  {'headline': 'Zika case reported in Abilene',
#   'cities': 'Abilene',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Palm Springs',
#   'cities': 'Palm Springs',
#   'countries': None},
#  {'headline': 'Halifax is infested with Swine Flu',
#   'cities': 'Halifax',
#   'countries': None},
#  {'headline': 'Zika arrives in Natal', 'cities': 'Natal', 'countries': None},
#  {'headline': 'Herpes Keeps Spreading in Rochester',
#   'cities': 'Rochester',
#   'countries': None},
#  {'headline': 'Zika case reported in Phetchabun',
#   'cities': 'Phetchabun',
#   'countries': None},
#  {'headline': 'How to Avoid Pneumonia in Bullhead City',
#   'cities': 'Bullhead City',
#   'countries': None},
#  {'headline': 'West Nile Virus re-emerges in Wellington',
#   'cities': 'Wellington',
#   'countries': None},
#  {'headline': 'Rumors about Pneumonia spreading in Ottawa have been refuted',
#   'cities': 'Ottawa',
#   'countries': None},
#  {'headline': 'Meningitis re-emerges in Summerville',
#   'cities': 'Summerville',
#   'countries': None},
#  {'headline': 'Pneumonia Symptoms Spread all over Bloomington',
#   'cities': 'Bloomington',
#   'countries': None},
#  {'headline': 'More Patients in Stuttgart are Getting Diagnosed with Rabies',
#   'cities': 'Stuttgart',
#   'countries': None},
#  {'headline': 'Schools in Glasgow Closed Due to Hepatitis B Outbreak',
#   'cities': 'Glasgow',
#   'countries': None},
#  {'headline': 'Phoenix Residents Recieve Syphilis vaccine',
#   'cities': 'Phoenix',
#   'countries': None},
#  {'headline': 'More people in Boucau are infected with HIV every year',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Spanish flu spreading in Madrid',
#   'cities': 'Madrid',
#   'countries': None},
#  {'headline': 'Rabies Hits Madrid', 'cities': 'Madrid', 'countries': None},
#  {'headline': 'Zika Outbreak in Weslaco',
#   'cities': 'Weslaco',
#   'countries': None},
#  {'headline': 'How to Avoid Chlamydia in Santiago',
#   'cities': 'Santiago',
#   'countries': None},
#  {'headline': 'Rotavirus Vaccine is now Required in Las Cumbres',
#   'cities': 'Las Cumbres',
#   'countries': None},
#  {'headline': 'Mumps Symptoms Spread all over Jefferson',
#   'cities': 'Jefferson',
#   'countries': None},
#  {'headline': 'Mad Cow Outbreak Spreading in Ennis',
#   'cities': 'Ennis',
#   'countries': None},
#  {'headline': 'Southampton Patient in Critical Condition after Contracting Tuberculosis',
#   'cities': 'Southampton',
#   'countries': None},
#  {'headline': 'The Spread of Rhinovirus in Boardman has been Confirmed',
#   'cities': 'Boardman',
#   'countries': None},
#  {'headline': 'Richland Center is infested with Hepatitis B',
#   'cities': 'Richland',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Chickenpox in Richmond',
#   'cities': 'Richmond',
#   'countries': None},
#  {'headline': 'Chikungunya re-emerges in Kobe',
#   'cities': 'Kobe',
#   'countries': None},
#  {'headline': 'Malaria Vaccine is now Required in Schenectady',
#   'cities': 'Schenectady',
#   'countries': None},
#  {'headline': 'Hepatitis D has Arrived in Grenoble',
#   'cities': 'Grenoble',
#   'countries': None},
#  {'headline': 'West Nile Virus Symptoms Spread all over Yerevan',
#   'cities': 'Yerevan',
#   'countries': None},
#  {'headline': 'Zika Outbreak in Sincelejo',
#   'cities': 'Sincelejo',
#   'countries': None},
#  {'headline': 'Rumors about HIV spreading in Montpellier have been refuted',
#   'cities': 'Montpellier',
#   'countries': None},
#  {'headline': 'Praia tests new cure for Pneumonia',
#   'cities': 'Praia',
#   'countries': None},
#  {'headline': 'Bronchitis Outbreak in Manhasset',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Lakewood after Hepatitis B Vaccine becomes Mandatory',
#   'cities': 'Lakewood',
#   'countries': None},
#  {'headline': 'Zika spreads to Kuching',
#   'cities': 'Kuching',
#   'countries': None},
#  {'headline': 'Spike of Rotavirus Cases in Omaha',
#   'cities': 'Omaha',
#   'countries': None},
#  {'headline': 'Tuberculosis re-emerges in Silver Springs',
#   'cities': 'Springs',
#   'countries': None},
#  {'headline': 'Will West Nile Virus vaccine help Coronado?',
#   'cities': 'Coronado',
#   'countries': None},
#  {'headline': 'Zika case confirmed in Lorain',
#   'cities': 'Lorain',
#   'countries': None},
#  {'headline': 'Chickenpox Hits Simpsonville',
#   'cities': 'Simpsonville',
#   'countries': None},
#  {'headline': 'Framingham Residents Receive Measles vaccine',
#   'cities': 'Framingham',
#   'countries': None},
#  {'headline': 'Rumors about Mad Cow Disease Brighton have been Refuted',
#   'cities': 'Brighton',
#   'countries': None},
#  {'headline': 'Zika case reported in Jacobina',
#   'cities': 'Jacobina',
#   'countries': None},
#  {'headline': 'Bridgeport authorities confirmed the spread of West Nile Virus',
#   'cities': 'Bridgeport',
#   'countries': None},
#  {'headline': 'Zika Troubles come to Padre Las Casas',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Measles Vaccine is now Required in Wailuku',
#   'cities': 'Wailuku',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Surat',
#   'cities': 'Surat',
#   'countries': None},
#  {'headline': 'Rumors about Influenza Spreading in Dobbs Ferry have been Refuted',
#   'cities': None,
#   'countries': None},
#  {'headline': 'More contaminated cattle reported in Bedford',
#   'cities': 'Bedford',
#   'countries': None},
#  {'headline': 'Zika in Tamarac!', 'cities': 'Tamarac', 'countries': None},
#  {'headline': 'Will Measles vaccine help Milford?',
#   'cities': 'Milford',
#   'countries': None},
#  {'headline': 'Spike of Norovirus Cases in Huddersfield',
#   'cities': 'Huddersfield',
#   'countries': None},
#  {'headline': 'Rhinovirus Hits Bakersfield',
#   'cities': 'Bakersfield',
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Papeete after Measles Vaccine becomes Mandatory',
#   'cities': 'Papeete',
#   'countries': None},
#  {'headline': 'Zika arrives in Udon Thani',
#   'cities': 'Udon Thani',
#   'countries': None},
#  {'headline': 'Spike of Dengue Cases in Stockholm',
#   'cities': 'Stockholm',
#   'countries': None},
#  {'headline': 'More people in Berkeley are infected with Swine Flu every year',
#   'cities': 'Berkeley',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Destin', 'cities': None, 'countries': None},
#  {'headline': 'Zika only the latest mosquito-borne threat to New Orleans',
#   'cities': 'New Orleans',
#   'countries': None},
#  {'headline': 'Will Swine Flu vaccine help Annapolis?',
#   'cities': 'Annapolis',
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Monroe after Hepatitis D Vaccine becomes Mandatory',
#   'cities': 'Monroe',
#   'countries': None},
#  {'headline': 'New medicine wipes out Dengue in Saginaw',
#   'cities': 'Saginaw',
#   'countries': None},
#  {'headline': 'Spike of Rhinovirus Cases in Sevierville',
#   'cities': 'Sevierville',
#   'countries': None},
#  {'headline': 'Duisburg up in Arms over Mad Cow Disease',
#   'cities': 'Duisburg',
#   'countries': None},
#  {'headline': 'New medicine wipes out Mumps in Saint Charles',
#   'cities': 'Saint Charles',
#   'countries': None},
#  {'headline': 'Case of Chikungunya Reported in Gaithersburg',
#   'cities': 'Gaithersburg',
#   'countries': None},
#  {'headline': 'How to Avoid Respiratory Syncytial Virus in San Bernardino',
#   'cities': 'San Bernardino',
#   'countries': None},
#  {'headline': 'Laventille authorities confirmed the spread of Rhinovirus',
#   'cities': 'Laventille',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Waco',
#   'cities': 'Waco',
#   'countries': None},
#  {'headline': 'Will Herpes vaccine help Newcastle?',
#   'cities': 'Newcastle',
#   'countries': None},
#  {'headline': 'Erie County sets Zika traps',
#   'cities': 'Erie',
#   'countries': None},
#  {'headline': 'More people in Huron are infected with Dengue every year',
#   'cities': None,
#   'countries': None},
#  {'headline': 'How to Avoid Norovirus in Greenville',
#   'cities': 'Greenville',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Calumpang',
#   'cities': 'Calumpang',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Quisqueya',
#   'cities': 'Quisqueya',
#   'countries': None},
#  {'headline': 'Rumors about Hepatitis D Spreading in Montreal have been Refuted',
#   'cities': 'Montreal',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Fortaleza',
#   'cities': 'Fortaleza',
#   'countries': None},
#  {'headline': 'Rumors about Bronchitis spreading in Bundaberg have been refuted',
#   'cities': 'Bundaberg',
#   'countries': None},
#  {'headline': 'Hepatitis A re-emerges in Stamford',
#   'cities': 'Stamford',
#   'countries': None},
#  {'headline': 'Schools in Huntington Closed Due to Rotavirus Outbreak',
#   'cities': 'Huntington',
#   'countries': None},
#  {'headline': 'Will Mad Cow Vaccine Help Bristol?',
#   'cities': 'Bristol',
#   'countries': None},
#  {'headline': 'Chickenpox Comes to Stillwater',
#   'cities': 'Stillwater',
#   'countries': None},
#  {'headline': 'The Spread of Meningitis in Imperial has been Confirmed',
#   'cities': 'Imperial',
#   'countries': None},
#  {'headline': 'Will Tuberculosis vaccine help Cherry Creek?',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Gympie Patient in Critical Condition after Contracting Chlamydia',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Case of Measles Reported in Springdale',
#   'cities': 'Springdale',
#   'countries': None},
#  {'headline': 'Norwalk Encounters Severe Symptoms of Malaria',
#   'cities': 'Norwalk',
#   'countries': None},
#  {'headline': 'Zika arrives in Orange City',
#   'cities': 'Orange',
#   'countries': None},
#  {'headline': 'Pilsen Encounters Severe Symptoms of Malaria',
#   'cities': 'Pilsen',
#   'countries': None},
#  {'headline': 'Will Hepatitis B vaccine help La Paz?',
#   'cities': 'La Paz',
#   'countries': None},
#  {'headline': 'Zika Outbreak in Puducherry',
#   'cities': 'Puducherry',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Carrollton',
#   'cities': 'Carrollton',
#   'countries': None},
#  {'headline': 'Will Rabies vaccine help Tangier?',
#   'cities': 'Tangier',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Iquitos',
#   'cities': 'Iquitos',
#   'countries': None},
#  {'headline': 'West Nile Virus Exposure in Racine',
#   'cities': 'Racine',
#   'countries': None},
#  {'headline': 'The Spread of Hepatitis E in Lansing has been Confirmed',
#   'cities': 'Lansing',
#   'countries': None},
#  {'headline': 'West Nile Virus Exposure in Alpharetta',
#   'cities': 'Alpharetta',
#   'countries': None},
#  {'headline': 'Pedro Juan Caballero Encounters Severe Symptoms of Pneumonia',
#   'cities': 'Pedro Juan Caballero',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Melbourne',
#   'cities': 'Melbourne',
#   'countries': None},
#  {'headline': 'Zika Troubles come to La Libertad',
#   'cities': 'La Libertad',
#   'countries': None},
#  {'headline': 'Herpes Vaccine is now Required in Mattoon',
#   'cities': 'Mattoon',
#   'countries': None},
#  {'headline': 'Kent is infested with Rabies',
#   'cities': 'Kent',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Bonita Springs',
#   'cities': 'Bonita Springs',
#   'countries': None},
#  {'headline': 'The Spread of Malaria in Brazzaville has been Confirmed',
#   'cities': 'Brazzaville',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Fort Myers',
#   'cities': 'Fort Myers',
#   'countries': None},
#  {'headline': 'Zika spreads to Lewisville',
#   'cities': 'Lewisville',
#   'countries': None},
#  {'headline': 'Ogden is infested with Gonorrhea',
#   'cities': 'Ogden',
#   'countries': None},
#  {'headline': 'Fort Hood Reports its First Zika Patient',
#   'cities': 'Fort Hood',
#   'countries': None},
#  {'headline': 'Huzhou Residents Receive Hepatitis B vaccine',
#   'cities': 'Huzhou',
#   'countries': None},
#  {'headline': 'New medicine wipes out Rabies in Newburgh',
#   'cities': 'Newburgh',
#   'countries': None},
#  {'headline': 'Iowa City Encounters Severe Symptoms of Rhinovirus',
#   'cities': 'Iowa City',
#   'countries': None},
#  {'headline': 'Spike of Rabies Cases in Managua',
#   'cities': 'Managua',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Santa Elena',
#   'cities': 'Santa Elena',
#   'countries': None},
#  {'headline': 'Mumps Hits Howard Beach',
#   'cities': 'Howard Beach',
#   'countries': None},
#  {'headline': 'The Spread of Gonorrhea in Reno has been Confirmed',
#   'cities': 'Reno',
#   'countries': None},
#  {'headline': 'How to Avoid Rhinovirus in Plainfield',
#   'cities': 'Plainfield',
#   'countries': None},
#  {'headline': 'Rumors about Varicella spreading in Carlsbad have been refuted',
#   'cities': 'Carlsbad',
#   'countries': None},
#  {'headline': 'Scranton authorities confirmed the spread of Gonorrhea',
#   'cities': 'Scranton',
#   'countries': None},
#  {'headline': 'Mad Cow Disease Disastrous to Brussels',
#   'cities': 'Brussels',
#   'countries': None},
#  {'headline': 'Zika spreads to Olinda', 'cities': 'Olinda', 'countries': None},
#  {'headline': 'Hallandale Beach a Victim of Zika Outbreak',
#   'cities': 'Hallandale Beach',
#   'countries': None},
#  {'headline': 'Rhinovirus re-emerges in Storrs',
#   'cities': 'Storrs',
#   'countries': None},
#  {'headline': 'Germantown authorities confirmed the spread of Chickenpox',
#   'cities': 'Germantown',
#   'countries': None},
#  {'headline': 'Rumors about Rotavirus spreading in North Platte have been refuted',
#   'cities': 'North Platte',
#   'countries': None},
#  {'headline': 'Spike of Hepatitis C Cases in Golden',
#   'cities': 'Golden',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Hepatitis D in Ganja',
#   'cities': 'Ganja',
#   'countries': None},
#  {'headline': 'Dengue Exposure in Kathmandu',
#   'cities': 'Kathmandu',
#   'countries': None},
#  {'headline': 'Tuberculosis has Arrived in Fairfield',
#   'cities': 'Fairfield',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Kozhikode',
#   'cities': 'Kozhikode',
#   'countries': None},
#  {'headline': 'Bronchitis Symptoms Spread all over Santa Fe',
#   'cities': 'Santa Fe',
#   'countries': None},
#  {'headline': 'More Patients in Alexandria are Getting Diagnosed with Mumps',
#   'cities': 'Alexandria',
#   'countries': None},
#  {'headline': 'Pneumonia Exposure in Alhambra',
#   'cities': 'Alhambra',
#   'countries': None},
#  {'headline': 'Hepatitis C re-emerges in Damascus',
#   'cities': 'Damascus',
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Pekanbaru after Rotavirus Vaccine becomes Mandatory',
#   'cities': 'Pekanbaru',
#   'countries': None},
#  {'headline': 'Spike of Meningitis Cases in Druid Hills',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Schools in Bentonville Closed Due to Hepatitis B Outbreak',
#   'cities': 'Bentonville',
#   'countries': None},
#  {'headline': 'Hepatitis E Hits Hammond',
#   'cities': 'Hammond',
#   'countries': None},
#  {'headline': 'Schools in Bridgeton Closed Due to Mumps Outbreak',
#   'cities': 'Bridgeton',
#   'countries': None},
#  {'headline': 'Biloxi Residents Recieve Chlamydia vaccine',
#   'cities': 'Biloxi',
#   'countries': None},
#  {'headline': 'Case of Mad Cow Disease Reported in Hilden',
#   'cities': 'Hilden',
#   'countries': None},
#  {'headline': 'Rumors about Rabies Spreading in Khartoum have been Refuted',
#   'cities': 'Khartoum',
#   'countries': None},
#  {'headline': 'Harare is infested with Pneumonia',
#   'cities': 'Harare',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Sibu',
#   'cities': 'Sibu',
#   'countries': None},
#  {'headline': 'Zika arrives in Quezon', 'cities': 'Quezon', 'countries': None},
#  {'headline': 'More Patients in Crawfordsville are Getting Diagnosed with Rabies',
#   'cities': 'Crawfordsville',
#   'countries': None},
#  {'headline': 'Spike of Hepatitis B Cases in Greenville',
#   'cities': 'Greenville',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Hepatitis D in Akron',
#   'cities': 'Akron',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Nuevo Laredo',
#   'cities': 'Nuevo Laredo',
#   'countries': None},
#  {'headline': 'Bronchitis Keeps Spreading in San Mateo',
#   'cities': 'San Mateo',
#   'countries': None},
#  {'headline': 'Zika arrives in Boca Raton',
#   'cities': 'Boca Raton',
#   'countries': None},
#  {'headline': 'Bradenton Experiences Zika Troubles',
#   'cities': 'Bradenton',
#   'countries': None},
#  {'headline': 'Chlamydia Symptoms Spread all over University City',
#   'cities': 'University City',
#   'countries': None},
#  {'headline': 'Wisconsin Rapids Patient in Critical Condition after Contracting Chickenpox',
#   'cities': 'Wisconsin Rapids',
#   'countries': None},
#  {'headline': 'Zika spreads to Kissimmee',
#   'cities': 'Kissimmee',
#   'countries': None},
#  {'headline': 'Herpes Symptoms Spread all over Fremont',
#   'cities': 'Fremont',
#   'countries': None},
#  {'headline': 'Spike of Pneumonia Cases in The Bronx',
#   'cities': 'The Bronx',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Hepatitis D in North Bay',
#   'cities': 'North Bay',
#   'countries': None},
#  {'headline': 'The Spread of Herpes in Baku has been Confirmed',
#   'cities': 'Baku',
#   'countries': None},
#  {'headline': 'Will Measles vaccine help Sochi?',
#   'cities': 'Sochi',
#   'countries': None},
#  {'headline': 'Tuberculosis Symptoms Spread all over Caguas',
#   'cities': 'Caguas',
#   'countries': None},
#  {'headline': 'HIV has Arrived in Tacoma',
#   'cities': 'Tacoma',
#   'countries': None},
#  {'headline': 'Malaria re-emerges in Nashua',
#   'cities': 'Nashua',
#   'countries': None},
#  {'headline': 'Arvada is infested with Syphilis',
#   'cities': 'Arvada',
#   'countries': None},
#  {'headline': 'Spike of Syphilis Cases in West Monroe',
#   'cities': 'Monroe',
# ...
#   'cities': 'Zanzibar',
#   'countries': None},
#  {'headline': "Malaria Outbreak Hits Zanzibar's Tourist Industry",
#   'cities': 'Zanzibar',
#   'countries': None},
#  {'headline': 'Tourist Perishes from Malaria in Arusha',
#   'cities': 'Arusha',
#   'countries': None},
#  {'headline': 'Herpes Symptoms Spread all over New Kingston',
#   'cities': 'New Kingston',
#   'countries': None},
#  {'headline': 'More people in Yokohama are infected with Norovirus every year',
#   'cities': 'Yokohama',
#   'countries': None},
#  {'headline': 'More people in Kitwe are infected with Respiratory Syncytial Virus every year',
#   'cities': 'Kitwe',
#   'countries': None},
#  {'headline': 'Hepatitis D Keeps Spreading in Bismarck',
#   'cities': 'Bismarck',
#   'countries': None},
#  {'headline': 'Varicella Outbreak in Minot',
#   'cities': 'Minot',
#   'countries': None},
#  {'headline': 'Malaria has Arrived in Terrebonne',
#   'cities': 'Terrebonne',
#   'countries': None},
#  {'headline': 'Chikungunya Keeps Spreading in North Vancouver',
#   'cities': 'North Vancouver',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Chickenpox in Hemet',
#   'cities': 'Hemet',
#   'countries': None},
#  {'headline': 'Fort Belvoir tests new cure for Hepatitis C',
#   'cities': None,
#   'countries': None},
#  {'headline': 'More people in Oak Brook are infected with Respiratory Syncytial Virus every year',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Rumors about Hepatitis C spreading in Darien have been refuted',
#   'cities': 'Darien',
#   'countries': None},
#  {'headline': 'The Spread of West Nile Virus in Fairfield has been Confirmed',
#   'cities': 'Fairfield',
#   'countries': None},
#  {'headline': 'Princeton Encounters Severe Symptoms of Dengue',
#   'cities': 'Princeton',
#   'countries': None},
#  {'headline': 'Norovirus Keeps Spreading in Copenhagen',
#   'cities': 'Copenhagen',
#   'countries': None},
#  {'headline': 'Wuhan is infested with Varicella',
#   'cities': 'Wuhan',
#   'countries': None},
#  {'headline': 'Zika spreads to San Luis Potosi',
#   'cities': 'San Luis Potosi',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Hutchins',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Spike of Norovirus Cases in Canberra',
#   'cities': 'Canberra',
#   'countries': None},
#  {'headline': 'Zika Troubles come to Greater Noida',
#   'cities': 'Greater Noida',
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Palm Springs after Hepatitis A Vaccine becomes Mandatory',
#   'cities': 'Palm Springs',
#   'countries': None},
#  {'headline': 'Longwood volunteers spreading Zika awareness',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Leesburg',
#   'cities': 'Leesburg',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Tuberculosis in Cantu',
#   'cities': 'Cantu',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Quixere',
#   'cities': None,
#   'countries': None},
#  {'headline': 'New medicine wipes out HIV in Kihei',
#   'cities': 'Kihei',
#   'countries': None},
#  {'headline': 'Sangre Grande Residents Recieve Gonorrhea vaccine',
#   'cities': 'Sangre Grande',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Colombo',
#   'cities': 'Colombo',
#   'countries': None},
#  {'headline': 'Will Rotavirus vaccine help Addis Ababa?',
#   'cities': 'Addis Ababa',
#   'countries': None},
#  {'headline': 'Stony Brook University experts discuss Zika virus',
#   'cities': 'University',
#   'countries': None},
#  {'headline': 'Lower Hospitalization in Janesville after Varicella Vaccine becomes Mandatory',
#   'cities': 'Janesville',
#   'countries': None},
#  {'headline': 'Rabies Outbreak in Altus',
#   'cities': 'Altus',
#   'countries': None},
#  {'headline': 'Miami resident suggests Zika precautions',
#   'cities': 'Miami',
#   'countries': None},
#  {'headline': 'Zika Troubles come to Jaen',
#   'cities': 'Jaen',
#   'countries': None},
#  {'headline': 'Hepatitis B Exposure in Edinburgh',
#   'cities': 'Edinburgh',
#   'countries': None},
#  {'headline': 'Zika case reported in Reynosa',
#   'cities': 'Reynosa',
#   'countries': None},
#  {'headline': 'Schools in Tulare Closed Due to Mumps Outbreak',
#   'cities': 'Tulare',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Chennai',
#   'cities': 'Chennai',
#   'countries': None},
#  {'headline': 'Hepatitis D Keeps Spreading in Danvers',
#   'cities': 'Danvers',
#   'countries': None},
#  {'headline': 'Authorities a Miami', 'cities': 'Miami', 'countries': None},
#  {'headline': 'Zika case reported in Medellin',
#   'cities': 'Medellin',
#   'countries': None},
#  {'headline': 'Spike of Tuberculosis Cases in Albuquerque',
#   'cities': 'Albuquerque',
#   'countries': None},
#  {'headline': 'More people in Cranford are infected with Hepatitis A every year',
#   'cities': 'Cranford',
#   'countries': None},
#  {'headline': 'West Nile Virus Hits Monroe',
#   'cities': 'Monroe',
#   'countries': None},
#  {'headline': 'Pneumonia Outbreak in Springville',
#   'cities': 'Springville',
#   'countries': None},
#  {'headline': 'Zika arrives in San Onofre',
#   'cities': 'San Onofre',
#   'countries': None},
#  {'headline': 'Lung Cancer Rates Increasing in Moscow',
#   'cities': 'Moscow',
#   'countries': None},
#  {'headline': 'Rumors about Rotavirus Spreading in Joliet have been Refuted',
#   'cities': 'Joliet',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Chanthaburi',
#   'cities': 'Chanthaburi',
#   'countries': None},
#  {'headline': 'Lawrenceville is infested with Dengue',
#   'cities': 'Lawrenceville',
#   'countries': None},
#  {'headline': 'Zika Reported in Ciudad Acuna',
#   'cities': 'Ciudad Acuna',
#   'countries': None},
#  {'headline': 'Zika case reported in Limoeiro',
#   'cities': 'Limoeiro',
#   'countries': None},
#  {'headline': 'Ibadan tests new cure for Malaria',
#   'cities': 'Ibadan',
#   'countries': None},
#  {'headline': 'Gonorrhea has Arrived in Avon Lake',
#   'cities': 'Avon Lake',
#   'countries': None},
#  {'headline': 'Pneumonia has not Left Kinshasa',
#   'cities': 'Kinshasa',
#   'countries': None},
#  {'headline': 'Respiratory Syncytial Virus Hits Henderson',
#   'cities': 'Henderson',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Lakeland',
#   'cities': 'Lakeland',
#   'countries': None},
#  {'headline': 'Malaria Vaccine is now Required in Winona',
#   'cities': 'Winona',
#   'countries': None},
#  {'headline': 'More Patients in Canton are Getting Diagnosed with Norovirus',
#   'cities': 'Canton',
#   'countries': None},
#  {'headline': 'Ronkonkoma is infested with Chickenpox',
#   'cities': 'Ronkonkoma',
#   'countries': None},
#  {'headline': 'Kedougou tests new cure for Hepatitis C',
#   'cities': 'Kedougou',
#   'countries': None},
#  {'headline': 'Gonorrhea Exposure in Norwalk',
#   'cities': 'Norwalk',
#   'countries': None},
#  {'headline': 'How to Avoid Rhinovirus in Medford',
#   'cities': 'Medford',
#   'countries': None},
#  {'headline': 'Hepatitis D Symptoms Spread all over Evansville',
#   'cities': 'Evansville',
#   'countries': None},
#  {'headline': 'New medicine wipes out Herpes in Bossier City',
#   'cities': 'Bossier City',
#   'countries': None},
#  {'headline': 'Pneumonia Exposure in San Jose',
#   'cities': 'San Jose',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Mad Cow Disease in Edinburgh',
#   'cities': 'Edinburgh',
#   'countries': None},
#  {'headline': 'Duluth Patient in Critical Condition after Contracting Rotavirus',
#   'cities': 'Duluth',
#   'countries': None},
#  {'headline': 'Measles Hits Davos', 'cities': None, 'countries': None},
#  {'headline': 'Norfolk tests new cure for Herpes',
#   'cities': 'Norfolk',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Botucatu',
#   'cities': 'Botucatu',
#   'countries': None},
#  {'headline': 'Manassas Encounters Severe Symptoms of Measles',
#   'cities': 'Manassas',
#   'countries': None},
#  {'headline': 'Fayetteville authorities confirmed the spread of HIV',
#   'cities': 'Fayetteville',
#   'countries': None},
#  {'headline': 'Varicella Exposure in Cambridge',
#   'cities': 'Cambridge',
#   'countries': None},
#  {'headline': 'Hepatitis A Vaccine is now Required in Fukushima',
#   'cities': 'Fukushima',
#   'countries': None},
#  {'headline': 'Zika Outbreak in South Miami',
#   'cities': 'Miami',
#   'countries': None},
#  {'headline': 'Hepatitis D Symptoms Spread all over North Bethesda',
#   'cities': 'North Bethesda',
#   'countries': None},
#  {'headline': 'Panama City’s first Zika related death',
#   'cities': 'Panama City',
#   'countries': 'Panama'},
#  {'headline': 'West Nile Virus has Arrived in Dongguan',
#   'cities': 'Dongguan',
#   'countries': None},
#  {'headline': 'Zika arrives in Belmopan',
#   'cities': 'Belmopan',
#   'countries': None},
#  {'headline': 'Zika seminars in Yuma County',
#   'cities': 'Yuma',
#   'countries': None},
#  {'headline': 'Rumors about Hepatitis E Spreading in Morristown have been Refuted',
#   'cities': 'Morristown',
#   'countries': None},
#  {'headline': 'Mumps Outbreak in Joplin',
#   'cities': 'Joplin',
#   'countries': None},
#  {'headline': 'Spike of Hepatitis E Cases in Morehead City',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Mumps in Corona',
#   'cities': 'Corona',
#   'countries': None},
#  {'headline': 'Schools in Danville Closed Due to Tuberculosis Outbreak',
#   'cities': 'Danville',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Alvorada',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Marquette tests new cure for Hepatitis A',
#   'cities': 'Marquette',
#   'countries': None},
#  {'headline': 'Norovirus Vaccine is now Required in Anaheim',
#   'cities': 'Anaheim',
#   'countries': None},
#  {'headline': 'Zika Outbreak in Manaus',
#   'cities': 'Manaus',
#   'countries': None},
#  {'headline': 'Zika spreads to Caucasia',
#   'cities': 'Caucasia',
#   'countries': None},
#  {'headline': 'Case of Malaria Reported in Aurora',
#   'cities': 'Aurora',
#   'countries': None},
#  {'headline': 'Manchester Residents Recieve Influenza vaccine',
#   'cities': 'Manchester',
#   'countries': None},
#  {'headline': 'Zika spreads to Kamphaeng Phet',
#   'cities': 'Kamphaeng Phet',
#   'countries': None},
#  {'headline': 'Rotavirus Vaccine is now Required in Labasa',
#   'cities': 'Labasa',
#   'countries': None},
#  {'headline': 'The Spread of Hepatitis E in Fargo has been Confirmed',
#   'cities': 'Fargo',
#   'countries': None},
#  {'headline': 'Zika Outbreak in Mexicali',
#   'cities': 'Mexicali',
#   'countries': None},
#  {'headline': 'West Nile Virus Keeps Spreading in Hauppauge',
#   'cities': 'Hauppauge',
#   'countries': None},
#  {'headline': 'Bronchitis Keeps Spreading in Hayward',
#   'cities': 'Hayward',
#   'countries': None},
#  {'headline': 'Schools in Coamo Closed Due to Rhinovirus Outbreak',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Zika arrives in Dangriga', 'cities': None, 'countries': None},
#  {'headline': 'Zika spreads to Plant City',
#   'cities': 'Plant City',
#   'countries': None},
#  {'headline': 'Chlamydia Exposure in Sanaa',
#   'cities': 'Sanaa',
#   'countries': None},
#  {'headline': 'Zika Reported in North Miami Beach',
#   'cities': 'North Miami Beach',
#   'countries': None},
#  {'headline': 'More Patients in Kensington are Getting Diagnosed with Varicella',
#   'cities': 'Kensington',
#   'countries': None},
#  {'headline': 'More Patients in Maynard are Getting Diagnosed with Syphilis',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Case of West Nile Virus Reported in Riverside',
#   'cities': 'Riverside',
#   'countries': None},
#  {'headline': 'Northfield Encounters Severe Symptoms of Herpes',
#   'cities': 'Northfield',
#   'countries': None},
#  {'headline': 'The Spread of Respiratory Syncytial Virus in Monroe has been Confirmed',
#   'cities': 'Monroe',
#   'countries': None},
#  {'headline': 'How to Avoid Hepatitis B in Trenton',
#   'cities': 'Trenton',
#   'countries': None},
#  {'headline': 'Zika Reported in Ilopango',
#   'cities': 'Ilopango',
#   'countries': None},
#  {'headline': 'Barstow Patient in Critical Condition after Contracting Herpes',
#   'cities': 'Barstow',
#   'countries': None},
#  {'headline': 'Hepatitis D Exposure in Aswan',
#   'cities': 'Aswan',
#   'countries': None},
#  {'headline': 'Will Gonorrhea vaccine help East Moline?',
#   'cities': 'East Moline',
#   'countries': None},
#  {'headline': 'New medicine wipes out Influenza in Redlands',
#   'cities': 'Redlands',
#   'countries': None},
#  {'headline': 'How to Avoid Contaminated Meat when Visiting Basel',
#   'cities': 'Basel',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Kampong Speu',
#   'cities': 'Kampong Speu',
#   'countries': None},
#  {'headline': 'Alameda Residents Recieve Rabies vaccine',
#   'cities': 'Alameda',
#   'countries': None},
#  {'headline': 'Mad Cow Disease Detected in Lyon',
#   'cities': 'Lyon',
#   'countries': None},
#  {'headline': 'Memphis Encounters Severe Symptoms of Swine Flu',
#   'cities': 'Memphis',
#   'countries': None},
#  {'headline': 'Zika Troubles come to Delray Beach',
#   'cities': 'Delray Beach',
#   'countries': None},
#  {'headline': 'How to Avoid Chikungunya in Hampton',
#   'cities': 'Hampton',
#   'countries': None},
#  {'headline': 'Zika Reported in Sao Jose',
#   'cities': 'Sao Jose',
#   'countries': None},
#  {'headline': 'Case of Norovirus Reported in Stratford',
#   'cities': 'Stratford',
#   'countries': None},
#  {'headline': 'How to Avoid Hepatitis E in South Bend',
#   'cities': 'South Bend',
#   'countries': None},
#  {'headline': 'Hepatitis C Outbreak in Bethlehem',
#   'cities': 'Bethlehem',
#   'countries': None},
#  {'headline': 'Davenport is infested with Dengue',
#   'cities': 'Davenport',
#   'countries': None},
#  {'headline': 'Rumors about Swine Flu spreading in Suzhou have been refuted',
#   'cities': 'Suzhou',
#   'countries': None},
#  {'headline': 'Malaria Vaccine is now Required in Elyria',
#   'cities': 'Elyria',
#   'countries': None},
#  {'headline': 'Zika case reported in Antioquia',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Case of Swine Flu Reported in Tbilisi',
#   'cities': 'Tbilisi',
#   'countries': None},
#  {'headline': 'Chikungunya has not Left Pismo Beach',
#   'cities': None,
#   'countries': None},
#  {'headline': 'Zika spreads to La Joya', 'cities': None, 'countries': None},
#  {'headline': 'Influenza Keeps Spreading in Suffolk',
#   'cities': 'Suffolk',
#   'countries': None},
#  {'headline': 'More people in Allentown are infected with Chlamydia every year',
#   'cities': 'Allentown',
#   'countries': None},
#  {'headline': 'Mad Cow Disease re-emerges in Bedford',
#   'cities': 'Bedford',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Hepatitis B in Yiwu',
#   'cities': 'Yiwu',
#   'countries': None},
#  {'headline': 'Zika Outbreak in Yurimaguas',
#   'cities': 'Yurimaguas',
#   'countries': None},
#  {'headline': 'Dengue Outbreak in Easton',
#   'cities': 'Easton',
#   'countries': None},
#  {'headline': 'Varicella has Arrived in Milton',
#   'cities': 'Milton',
#   'countries': None},
#  {'headline': 'New medicine wipes out Meningitis in Sevilla',
#   'cities': 'Sevilla',
#   'countries': None},
#  {'headline': 'Authorities are Worried about the Spread of Varicella in Clovis',
#   'cities': 'Clovis',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Fort Worth',
#   'cities': 'Fort Worth',
#   'countries': None},
#  {'headline': 'Zika symptoms spotted in Boynton Beach',
#   'cities': 'Boynton Beach',
#   'countries': None},
#  {'headline': 'Outbreak of Zika in Portoviejo',
#   'cities': 'Portoviejo',
#   'countries': None},
#  {'headline': 'Influenza Exposure in Muscat',
#   'cities': 'Muscat',
#   'countries': None},
#  {'headline': 'Rumors about Rabies spreading in Jerusalem have been refuted',
#   'cities': 'Jerusalem',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Indang',
#   'cities': 'Indang',
#   'countries': None},
#  {'headline': 'Suva authorities confirmed the spread of Rotavirus',
#   'cities': 'Suva',
#   'countries': None},
#  {'headline': 'More Zika patients reported in Bella Vista',
#   'cities': 'Bella Vista',
#   'countries': None},
#  {'headline': 'Zika Outbreak in Wichita Falls',
#   'cities': 'Wichita Falls',
#   'countries': None}]

# %% [markdown]
# # Step 2: Geolocation

# %%
df_new = pd.read_json('result_json.json')

# %%
df_new
# Out:
#                                               headline         cities  \
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil         Recife
# 4              Dallas man comes down with case of Zika         Dallas
# ..                                                 ...            ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      Jerusalem
# 646              More Zika patients reported in Indang         Indang
# 647  Suva authorities confirmed the spread of Rotav...           Suva
# 648         More Zika patients reported in Bella Vista    Bella Vista
# 649                     Zika Outbreak in Wichita Falls  Wichita Falls
#
#     countries
# 0        None
# 1        None
# 2        None
# 3      Brazil
# 4        None
# ..        ...
# 645      None
# 646      None
# 647      None
# 648      None
# 649      None
#
# [650 rows x 3 columns]

# %%
alternative_names = {unidecode.unidecode(city_dict['name']):city_dict['name'] for city_dict in cities.values()}

# %%
def extract_code_lat_long(city_name):
    #print(gc.get_cities_by_name(city_name))
    lst = gc.get_cities_by_name(city_name)
    if not lst and city_name in alternative_names:
        lst = gc.get_cities_by_name(alternative_names[city_name])
    best_cities =  sorted(lst, key=lambda x: list(x.values())[0]['population'],reverse=True)
    best_city= best_cities[0]
    #print(best_cities)
    code_lat_long = [(city['countrycode'],city['latitude'],city['longitude']) for city in best_city.values()]
    code, lat, long = code_lat_long[0]
    return code, lat, long
extract_code_lat_long('Milton')
# Out:
# ('CA', 43.51681, -79.88294)

# %%
#del df['countries']
df.fillna(value=pd.np.nan, inplace=True)
df.dropna(subset = ["cities"], inplace=True);
df
# Out:
#                                               headline         cities
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil         Recife
# 4              Dallas man comes down with case of Zika         Dallas
# ..                                                 ...            ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      Jerusalem
# 646              More Zika patients reported in Indang         Indang
# 647  Suva authorities confirmed the spread of Rotav...           Suva
# 648         More Zika patients reported in Bella Vista    Bella Vista
# 649                     Zika Outbreak in Wichita Falls  Wichita Falls
#
# [608 rows x 2 columns]

# %%
all_info = [extract_code_lat_long(city) for city in df['cities']]

# %%
df['latitude'] = [info[1] for info in all_info]
df['longitude'] = [info[2] for info in all_info]
df['code'] = [info[0] for info in all_info]
df
# Out:
#                                               headline         cities code  \
# 0                             Zika Outbreak Hits Miami          Miami   US
# 1                      Could Zika Reach New York City?  New York City   US
# 2                    First Case of Zika in Miami Beach    Miami Beach   US
# 3              Mystery Virus Spreads in Recife, Brazil         Recife   BR
# 4              Dallas man comes down with case of Zika         Dallas   US
# ..                                                 ...            ...  ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      Jerusalem   IL
# 646              More Zika patients reported in Indang         Indang   PH
# 647  Suva authorities confirmed the spread of Rotav...           Suva   FJ
# 648         More Zika patients reported in Bella Vista    Bella Vista   DO
# 649                     Zika Outbreak in Wichita Falls  Wichita Falls   US
#
#      latitude  longitude
# 0    25.77427  -80.19366
# 1    40.71427  -74.00597
# 2    25.79065  -80.13005
# 3    -8.05389  -34.88111
# 4    32.78306  -96.80667
# ..        ...        ...
# 645  31.76904   35.21633
# 646  14.19528  120.87694
# 647 -18.14161  178.44149
# 648  18.45539  -69.94540
# 649  33.91371  -98.49339
#
# [608 rows x 5 columns]
